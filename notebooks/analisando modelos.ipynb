# %%
import pandas as pd

# %%
ada = pd.read_pickle('./tunning/ada.pkl')
rf = pd.read_pickle('./tunning/rf.pkl')
lgbm = pd.read_pickle('./tunning/lgbm.pkl')

# %%
rf
# Out:
#          f1  threshold  n_estimators  max_depth  min_samples_leaf  \
# 8  0.880132       0.50         250.0       90.0               2.0
# 3  0.879079       0.52         250.0       90.0               3.0
# 9  0.878816       0.50         250.0       70.0               2.0
# 0  0.877895       0.53         250.0       70.0               3.0
# 1  0.877105       0.51         200.0       70.0               3.0
# 4  0.877105       0.53         250.0       70.0               1.0
# 7  0.876711       0.51         250.0       70.0               1.0
# 2  0.876447       0.56         250.0       70.0               1.0
# 6  0.876316       0.60         200.0       90.0               1.0
# 5  0.875132       0.57         250.0       90.0               3.0
#
#    min_samples_split
# 8                4.0
# 3                5.0
# 9                2.0
# 0                3.0
# 1                3.0
# 4                3.0
# 7                5.0
# 2                2.0
# 6                2.0
# ...

# %%
lgbm
# Out:
#          f1  threshold  learning_rate  num_leaves  n_estimators  \
# 9  0.873553       0.61          0.150        80.0         100.0
# 6  0.873421       0.50          0.150        80.0          50.0
# 5  0.873289       0.67          0.155        70.0         150.0
# 1  0.872500       0.68          0.200        70.0         200.0
# 4  0.872500       0.68          0.200        70.0         200.0
# 2  0.871842       0.66          0.165        80.0         200.0
# 3  0.871579       0.50          0.190        70.0         100.0
# 7  0.871447       0.64          0.170        85.0         150.0
# 0  0.869342       0.62          0.155        85.0         200.0
# 8  0.868553       0.50          0.190        75.0          50.0
#
#    min_child_weight  max_depth
# 9            0.0025       50.0
# 6            0.0025       90.0
# 5            0.0020       70.0
# 1            0.0010      130.0
# 4            0.0010       90.0
# 2            0.0020       70.0
# 3            0.0010       50.0
# ...
